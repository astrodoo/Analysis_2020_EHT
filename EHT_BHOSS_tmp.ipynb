# %%
from pyhamrds import bhoss
import matplotlib.pyplot as plt
import os
# %matplotlib inline

#datadir = "/lustre04/scratch/astrodoo/BHOSS_EHT/bhoss_MA05/Rh1/inc10/BHOSS_CODE"
#data = "Rh1_Rl1_sig1_i10_ph0_SgrA_Th_IMAGE_GRMHD_HAMR3D_EHT_MADS41A5_331.dat"

filename  = os.path.join(datadir, data)

figdir = os.environ['PYTHONFIG']
#bhoss.show_image(filename,ifreq=10,cmap='hot',out=os.path.join(figdir,'bhoss_img_David512_201.png'))
bhoss.show_image(filename,ifreq=0,cmap='hot') # Koushik's data - only 230GHz
# Out:
# ===================================== header ==================================
# width: 20.134000 Rg, offset: 0.000000 Rg, resolution: 1500, Number of obs. freqs: 81
# time: 9994.973143 Rg/c, inclination: 10.000000 deg, phi: 0.000000 deg, BH spin: 0.500000
# Luminosity correction: 3.386362e+21, Jansky correction: 4.285108e-02, Micro Arcsecond correction: 5.029644e+00
# Frequencies of intereset [GHz]: [230.]
# All-freq image is included (3rd column in image data): False
# ...
# N_obs_freqs (81) is different from the exact number of the selelcted frequencies (1): check obs_freqs!
# N_obs_freqs is now overlaid to len(obs_freqs)
# 6750000
# -101.26684243394799 101.26684243394799 -101.26684243394799 101.26684243394799
# (zmin,zmax)= 0.0 0.000764804
# Total flux = 2.034967 Jy at 230 GHz
# ...
# 241:54:55.299 - Start Program
# ...

# %% [markdown]
# # High res: inc10

# %%
from pyhamrds import bhoss
import os

#datadir = '/ccs/home/astrodoo/MEMW/BHOSS/BHOSS_CODE/outcomes/C3D2R512'
#data = 'GRRT_IMAGE_bhoss_data80.dat'

pydir = os.environ['PYTHONDATA']
#datadir = "/lustre04/scratch/astrodoo/BHOSS_EHT/bhoss_tmp/BHOSS_CODE"
datadir = os.path.join(pydir,'bhoss_tmp')
data = "Rh10_Rl1_sig1_i10_ph0_SgrA_Th_IMAGE_GRMHD_HAMR3D_EHT_MADS41A5_410.dat"

bhdata = bhoss.read_image(os.path.join(datadir,data),silent=False,ifreq=0)  # Koushik's data - only 230GHz
# Out:
# ===================================== header ==================================
# width: 20.134000 Rg, offset: 0.000000 Rg, resolution: 800, Number of obs. freqs: 81
# time: 9994.973143 Rg/c, inclination: 10.000000 deg, phi: 0.000000 deg, BH spin: 0.500000
# Luminosity correction: 1.190518e+22, Jansky correction: 1.506483e-01, Micro Arcsecond correction: 5.029644e+00
# Frequencies of intereset [GHz]: [230.]
# All-freq image is included (3rd column in image data): False
# ...
# N_obs_freqs (81) is different from the exact number of the selelcted frequencies (1): check self.obs_freqs!
# N_obs_freqs is now overlaid to len(self.obs_freqs)
# length of data: 1920000
# xmin: -101.266842, xmax: 101.266842, ymin: -101.266842, ymax: 101.266842
# intensity (min,max)= 0.0 0.000723869
# Total flux = 2.032978 Jy at 230 GHz

# %%
""" resize the image """
from pyhamrds import bhoss
import os

cut_muas = 90.

bhimg, xred, yred = bhoss.reduce_image(bhdata.intensity, cut_muas=cut_muas, x=bhdata.x, y=bhdata.y)

print("reduced xmin, xmax = %f, %f"%(np.min(xred),np.max(xred)))
print(np.shape(bhimg))
# Out:
# reduced xmin, xmax = -89.860064, 89.860064
# (710, 710)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(8,8))

vmax = 0.6
#cmap = 'inferno'
cmap = 'hot'
zmax = np.max(bhimg)
xmin,xmax,ymin,ymax = -cut_muas,cut_muas,-cut_muas,cut_muas

p = ax.imshow(bhimg/zmax,vmin=0.,vmax=vmax, origin='lower',extent=[xmin,xmax,ymin,ymax], cmap=cmap)
plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)
plt.subplots_adjust(left=0., right=1., top=1., bottom=0.)

#fig.tight_layout()
figdir = os.environ['PYTHONFIG']
fig.savefig(os.path.join(figdir,'EHT_MA05Rh10i10_hres90.png'))

# %% [markdown]
# # High res: inc50

# %%
from pyhamrds import bhoss
import os

#datadir = '/ccs/home/astrodoo/MEMW/BHOSS/BHOSS_CODE/outcomes/C3D2R512'
#data = 'GRRT_IMAGE_bhoss_data80.dat'

pydir = os.environ['PYTHONDATA']
#datadir = "/lustre04/scratch/astrodoo/BHOSS_EHT/bhoss_tmp/BHOSS_CODE"
datadir = os.path.join(pydir,'bhoss_tmp')
data = "Rh10_Rl1_sig1_i50_ph0_SgrA_Th_IMAGE_GRMHD_HAMR3D_EHT_MADS41A5_410.dat"

bhdata = bhoss.read_image(os.path.join(datadir,data),silent=False,ifreq=0)  # Koushik's data - only 230GHz
# Out:
# ===================================== header ==================================
# width: 20.134000 Rg, offset: 0.000000 Rg, resolution: 800, Number of obs. freqs: 81
# time: 9994.973143 Rg/c, inclination: 50.000000 deg, phi: 0.000000 deg, BH spin: 0.500000
# Luminosity correction: 1.190518e+22, Jansky correction: 1.506483e-01, Micro Arcsecond correction: 5.029644e+00
# Frequencies of intereset [GHz]: [230.]
# All-freq image is included (3rd column in image data): False
# ...
# N_obs_freqs (81) is different from the exact number of the selelcted frequencies (1): check self.obs_freqs!
# N_obs_freqs is now overlaid to len(self.obs_freqs)
# length of data: 1920000
# xmin: -101.266842, xmax: 101.266842, ymin: -101.266842, ymax: 101.266842
# intensity (min,max)= 7.9835e-11 0.00118661
# Total flux = 2.285344 Jy at 230 GHz

# %%
""" resize the image """
from pyhamrds import bhoss
import os

cut_muas = 90.

bhimg, xred, yred = bhoss.reduce_image(bhdata.intensity, cut_muas=cut_muas, x=bhdata.x, y=bhdata.y)

print("reduced xmin, xmax = %f, %f"%(np.min(xred),np.max(xred)))
print(np.shape(bhimg))
# Out:
# reduced xmin, xmax = -89.860064, 89.860064
# (710, 710)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(8,8))

vmax = 0.6
#cmap = 'inferno'
cmap = 'hot'
zmax = np.max(bhimg)
xmin,xmax,ymin,ymax = -cut_muas,cut_muas,-cut_muas,cut_muas

p = ax.imshow(bhimg/zmax,vmin=0.,vmax=vmax, origin='lower',extent=[xmin,xmax,ymin,ymax], cmap=cmap)
plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)
plt.subplots_adjust(left=0., right=1., top=1., bottom=0.)

#fig.tight_layout()
figdir = os.environ['PYTHONFIG']
fig.savefig(os.path.join(figdir,'EHT_MA05Rh10i50_hres90.png'))

# %% [markdown]
# # High res: inc90

# %%
from pyhamrds import bhoss
import os

#datadir = '/ccs/home/astrodoo/MEMW/BHOSS/BHOSS_CODE/outcomes/C3D2R512'
#data = 'GRRT_IMAGE_bhoss_data80.dat'

pydir = os.environ['PYTHONDATA']
#datadir = "/lustre04/scratch/astrodoo/BHOSS_EHT/bhoss_tmp/BHOSS_CODE"
datadir = os.path.join(pydir,'bhoss_tmp')
data = "Rh10_Rl1_sig1_i90_ph0_SgrA_Th_IMAGE_GRMHD_HAMR3D_EHT_MADS41A5_410.dat"

bhdata = bhoss.read_image(os.path.join(datadir,data),silent=False,ifreq=0)  # Koushik's data - only 230GHz
# Out:
# ===================================== header ==================================
# width: 20.134000 Rg, offset: 0.000000 Rg, resolution: 800, Number of obs. freqs: 81
# time: 9994.973143 Rg/c, inclination: 90.000000 deg, phi: 0.000000 deg, BH spin: 0.500000
# Luminosity correction: 1.190518e+22, Jansky correction: 1.506483e-01, Micro Arcsecond correction: 5.029644e+00
# Frequencies of intereset [GHz]: [230.]
# All-freq image is included (3rd column in image data): False
# ...
# N_obs_freqs (81) is different from the exact number of the selelcted frequencies (1): check self.obs_freqs!
# N_obs_freqs is now overlaid to len(self.obs_freqs)
# length of data: 1920000
# xmin: -101.266842, xmax: 101.266842, ymin: -101.266842, ymax: 101.266842
# intensity (min,max)= 3.66679e-27 0.00214442
# Total flux = 2.643411 Jy at 230 GHz

# %%
""" resize the image """
from pyhamrds import bhoss
import os

cut_muas = 90.

bhimg, xred, yred = bhoss.reduce_image(bhdata.intensity, cut_muas=cut_muas, x=bhdata.x, y=bhdata.y)

print("reduced xmin, xmax = %f, %f"%(np.min(xred),np.max(xred)))
print(np.shape(bhimg))
# Out:
# reduced xmin, xmax = -89.860064, 89.860064
# (710, 710)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(8,8))

vmax = 0.4
#cmap = 'inferno'
cmap = 'hot'
zmax = np.max(bhimg)
xmin,xmax,ymin,ymax = -cut_muas,cut_muas,-cut_muas,cut_muas

p = ax.imshow(bhimg/zmax,vmin=0.,vmax=vmax, origin='lower',extent=[xmin,xmax,ymin,ymax], cmap=cmap)
plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)
plt.subplots_adjust(left=0., right=1., top=1., bottom=0.)

#fig.tight_layout()
figdir = os.environ['PYTHONFIG']
fig.savefig(os.path.join(figdir,'EHT_MA05Rh10i90_hres90.png'))
