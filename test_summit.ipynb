# %%
import os
import numpy as np
from pyhamrds.readhamr import readhamr
import pyhamrds.readhamr as pyham

datadir = os.environ["HAMRDATA"]

#dir = "F:\\Doosoo\\HAMRR_CUDA_develop\\HAMR_GPU\\HAMR_CUDA"
#dir = "D:\\HAMR\\HAMR_CUDA_RC_SUMMIT_devel\\HAMR_GPU\\HAMR_CUDA\\C3D_6em16_128"
#dir = "D:\\HAMR\\HAMR_CUDA_RC_SUMMIT_devel\\HAMR_GPU\\HAMR_CUDA"

#dir = os.path.join(datadir,"test")
#dir = os.path.join(datadir,"C3D5em16FT3_MAD")
dir = os.path.join(datadir,"EHT_MADS41A93M")
#dir = os.path.join(datadir,"SgrA_proj/Weak_field")

os.chdir(dir)

#ds1 = readhamr(dir,30, raddata=False, gridall=True, interpolate_var=0,timechk=True, silent=False) #, \
#               lowres1=6,lowres2=8, lowres3=8)
#ds = readhamr(dir,30, raddata=False, raddata_h=0, gridall=True, interpolate_var=0,timechk=True, silent=False)
ds = pyham.rpar_new(100)

# %%
import os
import numpy as np
from pyhamrds.readhamr import readhamr
import pyhamrds.readhamr as pyham

datadir = os.environ["HAMRDATA"]

#dir = os.path.join(datadir,"EHT_MADS41A93M")  # 101 - 200
#dir = os.path.join(datadir,"EHT_MADS41A0")    # 97 - 196
#dir = os.path.join(datadir,"EHT_MADS41A93")    # 96 - 195

os.chdir(dir)

for i in range(90,210):
    ds = pyham.rpar_new(i)
    if ((ds.t>=9000.) and (ds.t<=10000.)):
        print('index of %d at time:%f'%(i,ds.t))
# Out:
# index of 96 at time:9008.139053
# index of 97 at time:9017.844868
# index of 98 at time:9027.551100
# index of 99 at time:9038.646851
# index of 100 at time:9048.356431
# index of 101 at time:9058.061637
# index of 102 at time:9067.764826
# index of 103 at time:9077.464542
# index of 104 at time:9088.552963
# index of 105 at time:9098.254801
# index of 106 at time:9107.957635
# index of 107 at time:9117.659184
# index of 108 at time:9127.363548
# index of 109 at time:9138.452062
# index of 110 at time:9148.158890
# index of 111 at time:9157.868704
# index of 112 at time:9167.579583
# index of 113 at time:9178.672003
# index of 114 at time:9188.377169
# index of 115 at time:9198.079088
# index of 116 at time:9207.781556
# index of 117 at time:9217.482565
# index of 118 at time:9228.573654
# index of 119 at time:9238.281441
# index of 120 at time:9247.990304
# index of 121 at time:9257.698128
# index of 122 at time:9267.401850
# index of 123 at time:9278.487308
# ...

# %%
print(ds.t)
# Out:
# 8991.5645680156

# %%
import os
import numpy as np
from pyhamrds.readhamr import readhamr
import pyhamrds.readhamr as pyham

datadir = os.environ["HAMRDATA"]

#dir = "F:\\Doosoo\\HAMRR_CUDA_develop\\HAMR_GPU\\HAMR_CUDA"
#dir = "D:\\HAMR\\HAMR_CUDA_RC_SUMMIT_devel\\HAMR_GPU\\HAMR_CUDA\\C3D_6em16_128"
#dir = "D:\\HAMR\\HAMR_CUDA_RC_SUMMIT_devel\\HAMR_GPU\\HAMR_CUDA"

#dir = os.path.join(datadir,"test")
#dir = os.path.join(datadir,"C3D5em16FT3_MAD")
dir = os.path.join(datadir,"EHT_S5R360MAD")
#dir = os.path.join(datadir,"SgrA_proj/Weak_field")

os.chdir(dir)

ds2 = readhamr(dir,0, raddata=False, gridall=True, interpolate_var=0,timechk=True, silent=False) #, \
#               lowres1=6,lowres2=8, lowres3=8)
#ds = readhamr(dir,30, raddata=False, raddata_h=0, gridall=True, interpolate_var=0,timechk=True, silent=False)
#ds = pyham.rdump_new(dir,0,raddata=True)
# Out:
# rblock_new: nmax=96
# rpar_new: t=0.000000, dt=0.000100, n_active=16, n_active_total=96, nstep=0
# rpar_new: Dtd=0.000000, Dtl=0.000000, Dtr=0.000000, dump_cnt=0, rdump_cnt=0
# rpar_new: bs1=60, bs2=44, bs3=44, nmax=96, nb1=6, nb2=4, nb3=4
# rpar_new: nb=96, nx=360, ny=176, nz=176
# rpar_new: startx1=0.461292, startx2=-0.988636, startx3=0.000000, _dx1=0.017907, _dx2=0.011235, _dx3=0.035700
# rpar_new: tf=8990.000000, a=0.500000, gam=1.444444, cour=0.900000, Rin=1.586122, Rout=1000.000000, R0=0.000000, fractheta=0.988636, rhor=1.866025
# rpar_new: DEREFINE_POLE=0, N_LEVELS_1D=0, N_LEVELS_3D=1
# rgdump_new: flag=0 (0=latest / 1=older version)
# rdump_new: flag=0 (0=latest / 1=older version)
# rdump_new: _dx1=0.017907, _dx2=0.011235, _dx3=0.035700
# readhamr: dir=/ccs/home/astrodoo/PRJW/EHT_S5R360MAD
# readhamr: dump=0
# readhamr: axisym=1, lowres1=1, lowres2=1, lowres3=1, raddata=0
# readhamr: mpi_cluster=0
# readhamr: REF_1=1, REF_2=1, REF_3=1, nRef=3
# ...

# %%
ds1.chkdata()
# Out:
# Passed the inspection~! Data is okay.

# %%
print(ds1.r[0,192,0,0])
# Out:
# 49.81714

# %%
print(np.log(ds1.r[0,100,0,0]), ds1.x1[0,100,0,0])
# Out:
# 2.2502701 2.2502701

# %%
print(ds1.x1[0,100,0,0]-ds1.x1[0,99,0,0])
# Out:
# 0.021036625

# %%
import os
import numpy as np
from pyhamrds.readhamr import readhamr
import pyhamrds.readhamr as pyham

datadir = os.environ["HAMRDATA"]

#dir = "F:\\Doosoo\\HAMRR_CUDA_develop\\HAMR_GPU\\HAMR_CUDA"
#dir = "D:\\HAMR\\HAMR_CUDA_RC_SUMMIT_devel\\HAMR_GPU\\HAMR_CUDA\\C3D_6em16_128"
#dir = "D:\\HAMR\\HAMR_CUDA_RC_SUMMIT_devel\\HAMR_GPU\\HAMR_CUDA"

dir = os.path.join(datadir,"NC3R256_MAD")

os.chdir(dir)

ds2 = readhamr(dir,36, raddata=False, gridall=True, interpolate_var=0,timechk=True, silent=False)
#ds = readhamr(dir,30, raddata=False, raddata_h=0, gridall=True, interpolate_var=0,timechk=True, silent=False)
#ds = pyham.rdump_new(dir,0,raddata=True)
# Out:
# rblock_new: nmax=64
# rpar_new: t=1800.581392, dt=0.007549, n_active=3, n_active_total=64, nstep=320640
# rpar_new: Dtd=50.000000, Dtl=50.000000, Dtr=0.000000, dump_cnt=36, rdump_cnt=37
# rpar_new: bs1=64, bs2=40, bs3=40, nmax=64, nb1=4, nb2=4, nb3=4
# rpar_new: nb=64, nx=256, ny=160, nz=160
# rpar_new: startx1=0.136092, startx2=-0.987500, startx3=0.000000, _dx1=0.021037, _dx2=0.012344, _dx3=0.039270
# rpar_new: tf=200000000.000000, a=0.937500, gam=1.666667, cour=0.900000, Rin=1.145787, Rout=250.000000, R0=0.000000, fractheta=0.987500, rhor=1.347985
# rpar_new: DEREFINE_POLE=0, N_LEVELS_1D=0, N_LEVELS_3D=1
# rgdump_new: flag=0 (0=latest / 1=older version)
# rdump_new: flag=0 (0=latest / 1=older version)
# rdump_new: _dx1=0.021037, _dx2=0.012344, _dx3=0.039270
# readhamr: dir=/ccs/home/astrodoo/PRJW/NC3R256_MAD
# readhamr: dump=36
# readhamr: axisym=1, lowres1=1, lowres2=1, lowres3=1, raddata=0
# readhamr: mpi_cluster=0
# readhamr: REF_1=1, REF_2=1, REF_3=1, nRef=3
# ...

# %%
from pyhamrds import showhamr as sz
import os
# %matplotlib inline 

ds1.set_pole()
figdir = os.environ["PYTHONFIG"]

#levs = np.logspace(-1,11,200)
#sz.plc_cart(ds.rho,data=ds,rmax=100,cmap='jet',nlevels=200)
sz.plc_cart(ds1.rho,data=ds1,logplt=True,cmap='jet',nlevels=200,rmax=100,extend='neither')
#sz.plc_cart(ds1,logplt=True,data=ds1,cmap='jet',nlevels=200, \
#            clabel=r'$\rho$ (code unit)')

# %%
from pyhamrds import showhamr as sz
import os
# %matplotlib inline 

ds1.set_pole()
figdir = os.environ["PYTHONFIG"]

levs = np.logspace(-7,1,200)
#sz.plc_cart(ds.rho,data=ds,rmax=100,cmap='jet',nlevels=200)
sz.plc_cart(ds2.rho,data=ds1,logplt=True,cmap='jet',levels=levs,rmax=100,extend='neither')
#sz.plc_cart(ds1,logplt=True,data=ds1,cmap='jet',nlevels=200, \
#            clabel=r'$\rho$ (code unit)')

# %%
print(11%5)
# Out:
# 1

# %%
from pyhamrds import showhamr as sz
import os
# %matplotlib inline 

ds2.set_pole()
figdir = os.environ["PYTHONFIG"]

levs = np.logspace(-7,2,200)
#sz.plc_cart(ds.rho,data=ds,rmax=100,cmap='jet',nlevels=200)
sz.plc_cart(ds2.rho,data=ds2,logplt=True,cmap='jet',nlevels=200,rmax=100,extend='neither')
#sz.plc_cart(ds1,logplt=True,data=ds1,cmap='jet',nlevels=200, \
#            clabel=r'$\rho$ (code unit)')

# %%
ds1.set_pole()
ds1.calc_T(TpTe_Model=0,TpoTe=3.33,Tlim=True)
# Out:
# mmw= 1.690000
# Te model: constant ratio of Tp/Te = 3.330000
# max Te= 2.400000e+11,  min Te=1.815150e+05

# %%
from pyhamrds import showhamr as sz
import os
# %matplotlib inline 

ds1.set_pole()
figdir = os.environ["PYTHONFIG"]

disk = (ds1.bsq/ds1.rho<1.)
print("maximum Te: %e"%np.max(ds1.Te*disk))

#sz.plc_cart(np.log10(ds.rho),data=ds,rmax=100,cmap='jet',nlevels=200)
sz.plc_cart(ds1.Te*disk,logplt=True,data=ds1,rmax=30,cmap='jet',levels=np.logspace(7.,11.5,200), \
            clabel=r'$\rho$ (code unit)')
# Out:
# maximum Te: 2.400000e+11

# %%
ds1.set_pole()
ds1.calc_T(TpTe_Model=0,TpoTe=3.33,Tlim=False)
# Out:
# mmw= 1.690000
# Te model: constant ratio of Tp/Te = 3.330000
# max Te= 7.653527e+12,  min Te=1.815150e+05

# %%
from pyhamrds import showhamr as sz
import os
# %matplotlib inline 

ds1.set_pole()
figdir = os.environ["PYTHONFIG"]

disk = (ds1.bsq/ds1.rho<1.)
Telim = (ds1.Te > 2.4e11)
print("maximum Te: %e"%np.max(ds1.Te*disk))

#sz.plc_cart(np.log10(ds.rho),data=ds,rmax=100,cmap='jet',nlevels=200)
sz.plc_cart(ds1.Te*disk*Telim,logplt=True,data=ds1,rmax=50,cmap='jet',levels=np.logspace(7.,11.5,200), \
            clabel=r'$\rho$ (code unit)')
# Out:
# maximum Te: 5.745790e+11

# %%
print(np.max())

# %%
from pyhamrds import showhamr as sz
import os
# %matplotlib inline 

ds2.set_pole()
figdir = os.environ["PYTHONFIG"]

#sz.plc_cart(np.log10(ds.rho),data=ds,rmax=100,cmap='jet',nlevels=200)
sz.plc_cart(ds2.rho,logplt=True,data=ds2,rmax=30,cmap='jet',nlevels=200, \
            clabel=r'$\rho$ (code unit)')

# %%
import os
import numpy as np
from pyhamrds.readhamr import readhamr
import pyhamrds.readhamr as pyham

datadir = os.environ["HAMRDATA"]

#dir = "F:\\Doosoo\\HAMRR_CUDA_develop\\HAMR_GPU\\HAMR_CUDA"
#dir = "D:\\HAMR\\HAMR_CUDA_RC_SUMMIT_devel\\HAMR_GPU\\HAMR_CUDA\\C3D_6em16_128"
#dir = "D:\\HAMR\\HAMR_CUDA_RC_SUMMIT_devel\\HAMR_GPU\\HAMR_CUDA"

dir = os.path.join(datadir,"C3D1o2R256_Rh20")

os.chdir(dir)

ds = readhamr(dir,100, raddata=True, gridall=True, interpolate_var=0,timechk=True, silent=False)
#ds = readhamr(dir,30, raddata=False, raddata_h=0, gridall=True, interpolate_var=0,timechk=True, silent=False)
#ds = pyham.rdump_new(dir,0,raddata=True)
# Out:
# rblock_new: nmax=64
# rpar_new: t=1001.425223, dt=0.007595, n_active=3, n_active_total=64, nstep=242560
# rpar_new: Dtd=10.000000, Dtl=10.000000, Dtr=0.000000, dump_cnt=100, rdump_cnt=101
# rpar_new: bs1=64, bs2=40, bs3=40, nmax=64, nb1=4, nb2=4, nb3=4
# rpar_new: nb=64, nx=256, ny=160, nz=160
# rpar_new: startx1=0.136092, startx2=-0.987500, startx3=0.000000, _dx1=0.021037, _dx2=0.012344, _dx3=0.039270
# rpar_new: tf=200000000.000000, a=0.937500, gam=1.666667, cour=0.900000, Rin=1.145787, Rout=250.000000, R0=0.000000, fractheta=0.987500, rhor=1.347985
# rpar_new: DEREFINE_POLE=0, N_LEVELS_1D=0, N_LEVELS_3D=1
# rpar_new: dscale=1.200000e-16, bhmass=4.100000e+06
# rgdump_new: flag=0 (0=latest / 1=older version)
# rdump_new: flag=0 (0=latest / 1=older version)
# rdump_new: _dx1=0.021037, _dx2=0.012344, _dx3=0.039270
# readhamr: dir=/ccs/home/astrodoo/PRJW/C3D1o2R256_Rh20
# readhamr: dump=100
# readhamr: axisym=1, lowres1=1, lowres2=1, lowres3=1, raddata=1
# readhamr: mpi_cluster=0
# ...

# %%
rr = ds.r[0,:,0,0]
rhi = (np.where(rr > ds.rhor))[0][0]
print(rhi)
# Out:
# 20

# %%
print(rr[rhi]-rr[rhi-1])
# Out:
# 0.011244297

# %%
import os
import numpy as np
from pyhamrds.readhamr import readhamr
import pyhamrds.readhamr as pyham

datadir = os.environ["HAMRDATA"]

#dir = "F:\\Doosoo\\HAMRR_CUDA_develop\\HAMR_GPU\\HAMR_CUDA"
#dir = "D:\\HAMR\\HAMR_CUDA_RC_SUMMIT_devel\\HAMR_GPU\\HAMR_CUDA\\C3D_6em16_128"
#dir = "D:\\HAMR\\HAMR_CUDA_RC_SUMMIT_devel\\HAMR_GPU\\HAMR_CUDA"

dir = os.path.join(datadir,"C3D2R512","reduced")

os.chdir(dir)

ds = readhamr(dir,20, raddata=True, gridall=True, interpolate_var=0,timechk=True, silent=False)
#ds = readhamr(dir,30, raddata=False, raddata_h=0, gridall=True, interpolate_var=0,timechk=True, silent=False)
#ds = pyham.rdump_new(dir,0,raddata=True)
# Out:
# rblock_new: nmax=336
# rpar_new: t=1002.446897, dt=0.002922, n_active=20, n_active_total=240, nstep=0
# rpar_new: Dtd=100.000000, Dtl=100.000000, Dtr=0.000000, dump_cnt=11, rdump_cnt=0
# rpar_new: bs1=27, bs2=16, bs3=12, nmax=336, nb1=6, nb2=6, nb3=4
# rpar_new: nb=240, nx=162, ny=96, nz=48
# rpar_new: startx1=0.136092, startx2=-0.994792, startx3=0.000000, _dx1=0.008311, _dx2=0.005181, _dx3=0.032725
# rpar_new: tf=200000000.000000, a=0.937500, gam=1.666667, cour=0.900000, Rin=1.145787, Rout=250.000000, R0=0.000000, fractheta=0.994792, rhor=1.347985
# rpar_new: DEREFINE_POLE=1, N_LEVELS_1D=1, N_LEVELS_3D=1
# rpar_new: dscale=2.000000e-16, bhmass=4.100000e+06
# rgdump_new: flag=0 (0=latest / 1=older version)
# rdump_new: flag=0 (0=latest / 1=older version)
# rdump_new: _dx1=0.008311, _dx2=0.005181, _dx3=0.032725
# readhamr: dir=/ccs/home/astrodoo/PRJW/C3D2R512/reduced
# readhamr: dump=20
# readhamr: axisym=1, lowres1=1, lowres2=1, lowres3=1, raddata=1
# readhamr: mpi_cluster=0
# ...

# %%
print(ds._dx1)
# Out:
# 0.008310754259634996

# %%
ds.chkdata()
# Out:
# Passed the inspection~! Data is okay.

# %%
from pyhamrds import showhamr as sz
import os
# %matplotlib inline 

ds.set_pole()
figdir = os.environ["PYTHONFIG"]

#sz.plc_cart(np.log10(ds.rho),data=ds,rmax=100,cmap='jet',nlevels=200)
sz.plc_cart(ds.rho,logplt=True,data=ds,rmax=50,cmap='jet',nlevels=200, \
            clabel=r'$\rho$ (code unit)')

# %%
from pyhamrds import showhamr as sz
import os
# %matplotlib inline 

ds.set_pole()
figdir = os.environ["PYTHONFIG"]

#sz.plc_cart(np.log10(ds.rho),data=ds,rmax=100,cmap='jet',nlevels=200)
sz.plc_cart(ds.rho,logplt=True,data=ds,rmax=20,cmap='jet',nlevels=200, \
            clabel=r'$\rho$ (code unit)', \
            out=os.path.join(figdir,"density_R512.png"))
# Out:
# saved to /ccs/home/astrodoo/pyResults/figures/density_R512.png

# %%
from pyhamrds import postprocess as pp
from pyds.astro import astrounit as unit

Mdot_rhor = pp.calc_Mdot_rhor(ds)
Mdot_rhor_cgs = Mdot_rhor * ds.dscale*(unit.g*ds.bhmass*unit.msun)**2./unit.c**3. / unit.msun*unit.year

print(ds.dscale,ds.bhmass)
print(Mdot_rhor,Mdot_rhor_cgs)
# Out:
# 6e-16 4600000.0
# 0.082455575 1.0852617111165339e-08

# %%
ds.chkdata()
# Out:
# Passed the inspection~! Data is okay.

# %%
from pyhamrds import showhamr as sz
# %matplotlib inline 

sz.plc_new((ds.bsq/ds.rho), data=ds, \
                 isfilled=1, xcoord=np.log10(ds.r),ycoord=ds.x2)

# %%
print(np.max(ds.radout[:]))
# Out:
# 643282600000.0

# %%
import numpy as np

print(np.shape(ds.rho))
# Out:
# (1, 96, 144, 48)

# %%
from pyhamrds import showhamr as sz
# %matplotlib inline 

res,ax = sz.plc_new(ds.radout[1], data=ds, logplt=True, cmap='jet', axout=True,\
                 isfilled=1, xcoord=np.log10(ds.r),ycoord=ds.x2)
ax.axvline(x=np.log10(ds.rhor))

# %%
print(ds.rhor)
# Out:
# 1.3479852726768764

# %%
import matplotlib.pyplot as plt
import os

# %matplotlib inline

fig = plt.figure()

blockid = 0
img2d = ds.rho[blockid,:,:,0]
img2d2 = ds.radout[3,blockid,:,:,0]
#img2d2 = ds.uu[3,blockid,:,:,0]

ax = fig.add_subplot(121) 
ax.imshow(np.log10(img2d),interpolation="None")
ax2 = fig.add_subplot(122)
ax2.imshow(np.log10(img2d2),interpolation="None")
ax2.axhline(y=6) # event horizon
# Out:
# C:\Users\astrodoo\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in log10
#   app.launch_new_instance()

# %%
from pyhamrds import showhamr as sz
# %matplotlib inline 

#sz.plc_cart(np.log10(ds.rho),data=ds,rmax=100,cmap='jet',nlevels=200)
sz.plc_cart(ds.rho,logplt=True,data=ds,rmax=150,cmap='jet',nlevels=200)

# %%
print(np.max(ds.rho))
# Out:
# 1.0

# %%
from pyhamrds import showhamr as sz
# %matplotlib inline 

#sz.plc_cart(np.log10(ds.rho),data=ds,rmax=100,cmap='jet',nlevels=200)
sz.plc_cart(ds.rho,logplt=True,data=ds,rmax=150,cmap='jet',nlevels=200)
