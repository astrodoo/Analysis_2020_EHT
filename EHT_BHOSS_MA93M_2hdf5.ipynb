# %% [markdown]
# # Rhigh & Rlow model (Moscibrodzka+16)

# %% [markdown]
# ## Check the data

# %%
from pyhamrds import bhoss
import os

#datadir = '/ccs/home/astrodoo/MEMW/BHOSS/BHOSS_CODE/outcomes/C3D2R512'
#data = 'GRRT_IMAGE_bhoss_data80.dat'

datadir = "/home/astrodoo/projects/rrg-dhaggard/astrodoo/EHT_bhoss/BHOSS_outcomes/bhoss_MA93M"
data = "Rh1_Rl1_sig1_i10_ph0_SgrA_Th_IMAGE_GRMHD_HAMR3D_EHT_MADS41A93M_150.dat"

bhdata = bhoss.read_image(os.path.join(datadir,data),silent=False,ifreq=0)  # Koushik's data - only 230GHz
# Out:
# ===================================== header ==================================
# width: 20.134000 Rg, offset: 0.000000 Rg, resolution: 400, Number of obs. freqs: 81
# time: 9490.865814 Rg/c, inclination: 10.000000 deg, phi: 0.000000 deg, BH spin: -0.937500
# Luminosity correction: 4.762071e+22, Jansky correction: 6.025933e-01, Micro Arcsecond correction: 5.029644e+00
# Frequencies of intereset [GHz]: [230.]
# All-freq image is included (3rd column in image data): False
# ...
# N_obs_freqs (81) is different from the exact number of the selelcted frequencies (1): check self.obs_freqs!
# N_obs_freqs is now overlaid to len(self.obs_freqs)
# length of data: 480000
# xmin: -101.266842, xmax: 101.266842, ymin: -101.266842, ymax: 101.266842
# intensity (min,max)= 0.0 0.000531341
# Total flux = 1.417960 Jy at 230 GHz

# %%
outdir = "/home/astrodoo/projects/rrg-dhaggard/astrodoo/EHT_bhoss/BHOSS_outcomes/bhoss2hdf5/bhoss_MA93M"
bhdata.dump2hdf5(outdir=outdir,source='SgrA', Rhigh=1, Rlow=1, sigmacut=1, betacrit=1, \
                 normflux=2., tilt=0.,acc='MAD',silent=False)
# Out:
# convert the bhoss file to hdf5 format: /home/astrodoo/projects/rrg-dhaggard/astrodoo/EHT_bhoss/BHOSS_outcomes/bhoss2hdf5/bhoss_MA93M/SgrA_MAD_a-0.94_i010_Rh001_Rl01_sigc01_snorm2.0_t09490_f230GHz_np0400_fov101_tilt0.00.h5

# %%
bhoss.checkhdf5(os.path.join(outdir,"SgrA_MAD_a-0.94_i010_Rh001_Rl01_sigc01_snorm2.0_t09490_f230GHz_np0400_fov101_tilt0.00.h5"))
# Out:
# /header/bh/acc MAD
# /header/bh/dbh 2.5077305106e+22
# /header/bh/fov 101
# /header/bh/inc 10.0
# /header/bh/mbh 8.234460000000001e+39
# /header/bh/spin -0.9375
# /header/bh/tilt 0.0
# /header/bh/time 9490.86581432085
# /header/camera/dx 40.26800000003976
# /header/camera/nx 400
# /header/dsource 2.5077305106e+22
# /header/emission/Rhigh 1
# /header/emission/Rlow 1
# /header/emission/betacrit 1
# /header/emission/fov 101
# /header/emission/janskycorr 0.6025932735218865
# /header/emission/lumcorr 4.762071055774303e+22
# /header/emission/microcorr 5.029643510174232
# /header/emission/normflux 2.0
# /header/emission/sigmacut 1
# /header/freqcgs 230000000000.0
# /header/scale 0.6025932735218865
# /header/t 9490.86581432085
# /header/units/L_unit 611495034824.0884
# /header/units/T_unit 20.397278800925953
# /unpol [[9.94481e-08 9.60705e-08 9.28380e-08 ... 1.46372e-07 1.42326e-07
#   1.39273e-07]
#  [9.96936e-08 9.48935e-08 9.11752e-08 ... 1.39660e-07 1.37325e-07
#   1.50227e-07]
# ...

# %% [markdown]
# ## batch script for the file conversion

# %%
from pyhamrds import bhoss
import os
def bhoss2hdf5(Rhigh=1,Rlow=1,sig=1,inclination=0,phi0=0,model_name='',source='SgrA'):

    if (model_name == "MADS41A5"):
        model_str = "bhoss_MA05"
        acc = 'MAD'
        ind_start = 311
        ind_end = 410
    elif (model_name == "MADS41A0"):
        model_str = "bhoss_MA0"
        acc = 'MAD'
        ind_start = 97
        ind_end = 196
    elif (model_name == "MADS41A93"):
        model_str = "bhoss_MA93"
        acc = 'MAD'
        ind_start = 96
        ind_end = 195
    elif (model_name == "MADS41A93M"):
        model_str = "bhoss_MA93M"
        acc = 'MAD'
        ind_start = 101
        ind_end = 200
    elif (model_name == "SANEA93M"):
        model_str = "bhoss_SA93M"
        acc = 'SANE'
        ind_start=132
        ind_end = 231
    elif (model_name == "SANEA93"):
        model_str = "bhoss_SA93"
        acc = 'SANE'
        ind_start=99
        ind_end = 198
    else:
        print("no model")
        return
    
    basedir = "/home/astrodoo/projects/rrg-dhaggard/astrodoo/EHT_bhoss/BHOSS_outcomes"
    datadir = os.path.join(basedir,model_str)
    outdir = os.path.join(basedir,"bhoss2hdf5",model_str)
    
    #ind_start=400
    #ind_end=400
    for image_ind in range(ind_start,ind_end+1):
        print("%d out of %d"%(image_ind,ind_end))
        
        data_name="Rh%d_Rl%d_sig%d_i%d_ph%d_SgrA_Th_IMAGE_GRMHD_HAMR3D_EHT_%s_%d.dat" \
                  %(Rhigh,Rlow,sig,inclination,phi0,model_name,image_ind)
        
        bhdata = bhoss.read_image(os.path.join(datadir,data_name),silent=True,ifreq=0)
        bhdata.dump2hdf5(outdir=outdir,source=source,Rhigh=Rhigh,Rlow=Rlow,sigmacut=sig,acc=acc, \
                         betacrit=1., normflux=2., tilt=0., silent=True)

# %%
bhoss2hdf5(model_name='MADS41A93M',Rhigh=1,inclination=10,Rlow=1,sig=1,phi0=0,source='SgrA')
# Out:
# 101 out of 200
# 102 out of 200
# 103 out of 200
# 104 out of 200
# 105 out of 200
# 106 out of 200
# 107 out of 200
# 108 out of 200
# 109 out of 200
# 110 out of 200
# 111 out of 200
# 112 out of 200
# 113 out of 200
# 114 out of 200
# 115 out of 200
# 116 out of 200
# 117 out of 200
# 118 out of 200
# 119 out of 200
# 120 out of 200
# 121 out of 200
# 122 out of 200
# 123 out of 200
# 124 out of 200
# 125 out of 200
# 126 out of 200
# 127 out of 200
# 128 out of 200
# 129 out of 200
# 130 out of 200
# 131 out of 200
# 132 out of 200
# 133 out of 200
# 134 out of 200
# 135 out of 200
# 136 out of 200
# 137 out of 200
# 138 out of 200
# 139 out of 200
# 140 out of 200
# 141 out of 200
# 142 out of 200
# 143 out of 200
# 144 out of 200
# 145 out of 200
# 146 out of 200
# 147 out of 200
# 148 out of 200
# 149 out of 200
# 150 out of 200
# 151 out of 200
# 152 out of 200
# 153 out of 200
# 154 out of 200
# 155 out of 200
# 156 out of 200
# 157 out of 200
# 158 out of 200
# ...

# %%
bhoss2hdf5(model_name='MADS41A93M',Rhigh=1,inclination=50,Rlow=1,sig=1,phi0=0,source='SgrA')
# Out:
# 101 out of 200
# 102 out of 200
# 103 out of 200
# 104 out of 200
# 105 out of 200
# 106 out of 200
# 107 out of 200
# 108 out of 200
# 109 out of 200
# 110 out of 200
# 111 out of 200
# 112 out of 200
# 113 out of 200
# 114 out of 200
# 115 out of 200
# 116 out of 200
# 117 out of 200
# 118 out of 200
# 119 out of 200
# 120 out of 200
# 121 out of 200
# 122 out of 200
# 123 out of 200
# 124 out of 200
# 125 out of 200
# 126 out of 200
# 127 out of 200
# 128 out of 200
# 129 out of 200
# 130 out of 200
# 131 out of 200
# 132 out of 200
# 133 out of 200
# 134 out of 200
# 135 out of 200
# 136 out of 200
# 137 out of 200
# 138 out of 200
# 139 out of 200
# 140 out of 200
# 141 out of 200
# 142 out of 200
# 143 out of 200
# 144 out of 200
# 145 out of 200
# 146 out of 200
# 147 out of 200
# 148 out of 200
# 149 out of 200
# 150 out of 200
# 151 out of 200
# 152 out of 200
# 153 out of 200
# 154 out of 200
# 155 out of 200
# 156 out of 200
# 157 out of 200
# 158 out of 200
# ...

# %%
bhoss2hdf5(model_name='MADS41A93M',Rhigh=1,inclination=90,Rlow=1,sig=1,phi0=0,source='SgrA')
# Out:
# 101 out of 200
# 102 out of 200
# 103 out of 200
# 104 out of 200
# 105 out of 200
# 106 out of 200
# 107 out of 200
# 108 out of 200
# 109 out of 200
# 110 out of 200
# 111 out of 200
# 112 out of 200
# 113 out of 200
# 114 out of 200
# 115 out of 200
# 116 out of 200
# 117 out of 200
# 118 out of 200
# 119 out of 200
# 120 out of 200
# 121 out of 200
# 122 out of 200
# 123 out of 200
# 124 out of 200
# 125 out of 200
# 126 out of 200
# 127 out of 200
# 128 out of 200
# 129 out of 200
# 130 out of 200
# 131 out of 200
# 132 out of 200
# 133 out of 200
# 134 out of 200
# 135 out of 200
# 136 out of 200
# 137 out of 200
# 138 out of 200
# 139 out of 200
# 140 out of 200
# 141 out of 200
# 142 out of 200
# 143 out of 200
# 144 out of 200
# 145 out of 200
# 146 out of 200
# 147 out of 200
# 148 out of 200
# 149 out of 200
# 150 out of 200
# 151 out of 200
# 152 out of 200
# 153 out of 200
# 154 out of 200
# 155 out of 200
# 156 out of 200
# 157 out of 200
# 158 out of 200
# ...

# %%
bhoss2hdf5(model_name='MADS41A93M',Rhigh=40,inclination=10,Rlow=1,sig=1,phi0=0,source='SgrA')
# Out:
# 101 out of 200
# 102 out of 200
# 103 out of 200
# 104 out of 200
# 105 out of 200
# 106 out of 200
# 107 out of 200
# 108 out of 200
# 109 out of 200
# 110 out of 200
# 111 out of 200
# 112 out of 200
# 113 out of 200
# 114 out of 200
# 115 out of 200
# 116 out of 200
# 117 out of 200
# 118 out of 200
# 119 out of 200
# 120 out of 200
# 121 out of 200
# 122 out of 200
# 123 out of 200
# 124 out of 200
# 125 out of 200
# 126 out of 200
# 127 out of 200
# 128 out of 200
# 129 out of 200
# 130 out of 200
# 131 out of 200
# 132 out of 200
# 133 out of 200
# 134 out of 200
# 135 out of 200
# 136 out of 200
# 137 out of 200
# 138 out of 200
# 139 out of 200
# 140 out of 200
# 141 out of 200
# 142 out of 200
# 143 out of 200
# 144 out of 200
# 145 out of 200
# 146 out of 200
# 147 out of 200
# 148 out of 200
# 149 out of 200
# 150 out of 200
# 151 out of 200
# 152 out of 200
# 153 out of 200
# 154 out of 200
# 155 out of 200
# 156 out of 200
# 157 out of 200
# 158 out of 200
# ...

# %%
bhoss2hdf5(model_name='MADS41A93M',Rhigh=40,inclination=50,Rlow=1,sig=1,phi0=0,source='SgrA')
# Out:
# 101 out of 200
# 102 out of 200
# 103 out of 200
# 104 out of 200
# 105 out of 200
# 106 out of 200
# 107 out of 200
# 108 out of 200
# 109 out of 200
# 110 out of 200
# 111 out of 200
# 112 out of 200
# 113 out of 200
# 114 out of 200
# 115 out of 200
# 116 out of 200
# 117 out of 200
# 118 out of 200
# 119 out of 200
# 120 out of 200
# 121 out of 200
# 122 out of 200
# 123 out of 200
# 124 out of 200
# 125 out of 200
# 126 out of 200
# 127 out of 200
# 128 out of 200
# 129 out of 200
# 130 out of 200
# 131 out of 200
# 132 out of 200
# 133 out of 200
# 134 out of 200
# 135 out of 200
# 136 out of 200
# 137 out of 200
# 138 out of 200
# 139 out of 200
# 140 out of 200
# 141 out of 200
# 142 out of 200
# 143 out of 200
# 144 out of 200
# 145 out of 200
# 146 out of 200
# 147 out of 200
# 148 out of 200
# 149 out of 200
# 150 out of 200
# 151 out of 200
# 152 out of 200
# 153 out of 200
# 154 out of 200
# 155 out of 200
# 156 out of 200
# 157 out of 200
# 158 out of 200
# ...

# %%
bhoss2hdf5(model_name='MADS41A93M',Rhigh=40,inclination=90,Rlow=1,sig=1,phi0=0,source='SgrA')
# Out:
# 101 out of 200
# 102 out of 200
# 103 out of 200
# 104 out of 200
# 105 out of 200
# 106 out of 200
# 107 out of 200
# 108 out of 200
# 109 out of 200
# 110 out of 200
# 111 out of 200
# 112 out of 200
# 113 out of 200
# 114 out of 200
# 115 out of 200
# 116 out of 200
# 117 out of 200
# 118 out of 200
# 119 out of 200
# 120 out of 200
# 121 out of 200
# 122 out of 200
# 123 out of 200
# 124 out of 200
# 125 out of 200
# 126 out of 200
# 127 out of 200
# 128 out of 200
# 129 out of 200
# 130 out of 200
# 131 out of 200
# 132 out of 200
# 133 out of 200
# 134 out of 200
# 135 out of 200
# 136 out of 200
# 137 out of 200
# 138 out of 200
# 139 out of 200
# 140 out of 200
# 141 out of 200
# 142 out of 200
# 143 out of 200
# 144 out of 200
# 145 out of 200
# 146 out of 200
# 147 out of 200
# 148 out of 200
# 149 out of 200
# 150 out of 200
# 151 out of 200
# 152 out of 200
# 153 out of 200
# 154 out of 200
# 155 out of 200
# 156 out of 200
# 157 out of 200
# 158 out of 200
# ...

# %%
bhoss2hdf5(model_name='MADS41A93M',Rhigh=160,inclination=10,Rlow=1,sig=1,phi0=0,source='SgrA')
# Out:
# 101 out of 200
# 102 out of 200
# 103 out of 200
# 104 out of 200
# 105 out of 200
# 106 out of 200
# 107 out of 200
# 108 out of 200
# 109 out of 200
# 110 out of 200
# 111 out of 200
# 112 out of 200
# 113 out of 200
# 114 out of 200
# 115 out of 200
# 116 out of 200
# 117 out of 200
# 118 out of 200
# 119 out of 200
# 120 out of 200
# 121 out of 200
# 122 out of 200
# 123 out of 200
# 124 out of 200
# 125 out of 200
# 126 out of 200
# 127 out of 200
# 128 out of 200
# 129 out of 200
# 130 out of 200
# 131 out of 200
# 132 out of 200
# 133 out of 200
# 134 out of 200
# 135 out of 200
# 136 out of 200
# 137 out of 200
# 138 out of 200
# 139 out of 200
# 140 out of 200
# 141 out of 200
# 142 out of 200
# 143 out of 200
# 144 out of 200
# 145 out of 200
# 146 out of 200
# 147 out of 200
# 148 out of 200
# 149 out of 200
# 150 out of 200
# 151 out of 200
# 152 out of 200
# 153 out of 200
# 154 out of 200
# 155 out of 200
# 156 out of 200
# 157 out of 200
# 158 out of 200
# ...

# %%
bhoss2hdf5(model_name='MADS41A93M',Rhigh=160,inclination=50,Rlow=1,sig=1,phi0=0,source='SgrA')
# Out:
# 101 out of 200
# 102 out of 200
# 103 out of 200
# 104 out of 200
# 105 out of 200
# 106 out of 200
# 107 out of 200
# 108 out of 200
# 109 out of 200
# 110 out of 200
# 111 out of 200
# 112 out of 200
# 113 out of 200
# 114 out of 200
# 115 out of 200
# 116 out of 200
# 117 out of 200
# 118 out of 200
# 119 out of 200
# 120 out of 200
# 121 out of 200
# 122 out of 200
# 123 out of 200
# 124 out of 200
# 125 out of 200
# 126 out of 200
# 127 out of 200
# 128 out of 200
# 129 out of 200
# 130 out of 200
# 131 out of 200
# 132 out of 200
# 133 out of 200
# 134 out of 200
# 135 out of 200
# 136 out of 200
# 137 out of 200
# 138 out of 200
# 139 out of 200
# 140 out of 200
# 141 out of 200
# 142 out of 200
# 143 out of 200
# 144 out of 200
# 145 out of 200
# 146 out of 200
# 147 out of 200
# 148 out of 200
# 149 out of 200
# 150 out of 200
# 151 out of 200
# 152 out of 200
# 153 out of 200
# 154 out of 200
# 155 out of 200
# 156 out of 200
# 157 out of 200
# 158 out of 200
# ...

# %%
bhoss2hdf5(model_name='MADS41A93M',Rhigh=160,inclination=90,Rlow=1,sig=1,phi0=0,source='SgrA')
# Out:
# 101 out of 200
# 102 out of 200
# 103 out of 200
# 104 out of 200
# 105 out of 200
# 106 out of 200
# 107 out of 200
# 108 out of 200
# 109 out of 200
# 110 out of 200
# 111 out of 200
# 112 out of 200
# 113 out of 200
# 114 out of 200
# 115 out of 200
# 116 out of 200
# 117 out of 200
# 118 out of 200
# 119 out of 200
# 120 out of 200
# 121 out of 200
# 122 out of 200
# 123 out of 200
# 124 out of 200
# 125 out of 200
# 126 out of 200
# 127 out of 200
# 128 out of 200
# 129 out of 200
# 130 out of 200
# 131 out of 200
# 132 out of 200
# 133 out of 200
# 134 out of 200
# 135 out of 200
# 136 out of 200
# 137 out of 200
# 138 out of 200
# 139 out of 200
# 140 out of 200
# 141 out of 200
# 142 out of 200
# 143 out of 200
# 144 out of 200
# 145 out of 200
# 146 out of 200
# 147 out of 200
# 148 out of 200
# 149 out of 200
# 150 out of 200
# 151 out of 200
# 152 out of 200
# 153 out of 200
# 154 out of 200
# 155 out of 200
# 156 out of 200
# 157 out of 200
# 158 out of 200
# ...

# %% [markdown]
# # Critical beta model (Anantua+20)

# %% [markdown]
# ## Check the data

# %%
from pyhamrds import bhoss
import os

#datadir = '/ccs/home/astrodoo/MEMW/BHOSS/BHOSS_CODE/outcomes/C3D2R512'
#data = 'GRRT_IMAGE_bhoss_data80.dat'

datadir = "/home/astrodoo/projects/rrg-dhaggard/astrodoo/EHT_bhoss/BHOSS_outcomes/bhoss_MA93M"
data = "f05_b1_sig1_i10_ph0_SgrA_Th_IMAGE_GRMHD_HAMR3D_EHT_MADS41A93M_110.dat"

bhdata = bhoss.read_image(os.path.join(datadir,data),silent=False,ifreq=2)  # Koushik's data - only 230GHz
# Out:
# ===================================== header ==================================
# width: 20.134000 Rg, offset: 0.000000 Rg, resolution: 400, Number of obs. freqs: 5
# time: 9090.952675 Rg/c, inclination: 10.000000 deg, phi: 0.000000 deg, BH spin: -0.937500
# Luminosity correction: 4.762071e+22, Jansky correction: 6.025933e-01, Micro Arcsecond correction: 5.029644e+00
# Frequencies of intereset [GHz]: [  43.   86.  230.  345. 1360.]
# All-freq image is included (3rd column in image data): False
# ...
# length of data: 480000
# xmin: -101.266842, xmax: 101.266842, ymin: -101.266842, ymax: 101.266842
# intensity (min,max)= 0.0 0.00105012
# Total flux = 2.144696 Jy at 230 GHz

# %%
outdir = "/home/astrodoo/projects/rrg-dhaggard/astrodoo/EHT_bhoss/BHOSS_outcomes/bhoss2hdf5/bhoss_MA93M"
bhdata.dump2hdf5(outdir=outdir,source='SgrA', sigmacut=1, betacrit=1, f_ana=0.5, \
                 normflux=2., tilt=0.,acc='MAD',silent=False)
# Out:
# convert the bhoss file to hdf5 format: /home/astrodoo/projects/rrg-dhaggard/astrodoo/EHT_bhoss/BHOSS_outcomes/bhoss2hdf5/bhoss_MA93M/SgrA_MAD_a-0.94_i010_fa0.5_bc1.00_sigc01_snorm2.0_t09090_f230GHz_np0400_fov101_tilt0.00.h5

# %%
bhoss.checkhdf5(os.path.join(outdir,"SgrA_MAD_a-0.94_i010_fa0.5_bc1.00_sigc01_snorm2.0_t09090_f230GHz_np0400_fov101_tilt0.00.h5"))
# Out:
# /header/bh/acc MAD
# /header/bh/dbh 2.5077305106e+22
# /header/bh/fov 101
# /header/bh/inc 10.0
# /header/bh/mbh 8.234460000000001e+39
# /header/bh/spin -0.9375
# /header/bh/tilt 0.0
# /header/bh/time 9090.952675383893
# /header/camera/dx 40.26800000003976
# /header/camera/nx 400
# /header/dsource 2.5077305106e+22
# /header/emission/betacrit 1
# /header/emission/f_ana 0.5
# /header/emission/fov 101
# /header/emission/janskycorr 0.6025932735218865
# /header/emission/lumcorr 4.762071055774303e+22
# /header/emission/microcorr 5.029643510174232
# /header/emission/normflux 2.0
# /header/emission/sigmacut 1
# /header/freqcgs 230000000000.0
# /header/scale 0.6025932735218865
# /header/t 9090.952675383893
# /header/units/L_unit 611495034824.0884
# /header/units/T_unit 20.397278800925953
# /unpol [[5.30658e-07 5.29401e-07 4.96043e-07 ... 2.91038e-09 2.77712e-09
#   2.65729e-09]
#  [5.45987e-07 5.30659e-07 4.83870e-07 ... 2.58888e-09 2.58833e-09
#   2.58993e-09]
# ...

# %% [markdown]
# ## batch script for the file conversion

# %%
from pyhamrds import bhoss
import os
def bhoss2hdf5(Te_model='f05_b1',sig=1,inclination=0,phi0=0,model_name='',source='SgrA'):

    if (model_name == "MADS41A5"):
        model_str = "bhoss_MA05"
        acc = 'MAD'
        ind_start = 311
        ind_end = 410
    elif (model_name == "MADS41A0"):
        model_str = "bhoss_MA0"
        acc = 'MAD'
        ind_start = 97
        ind_end = 196
    elif (model_name == "MADS41A93M"):
        model_str = "bhoss_MA93M"
        acc = 'MAD'
        ind_start = 101
        ind_end = 200
    elif (model_name == "SANEA93M"):
        model_str = "bhoss_SA93M"
        acc = 'SANE'
        ind_start=132
        ind_end = 231
    elif (model_name == "SANEA93"):
        model_str = "bhoss_SA93"
        acc = 'SANE'
        ind_start=99
        ind_end = 198
    else:
        print("no model")
        return
    
    if (Te_model=='f05_b1'):
        f_ana = 0.5
        betacrit=1.
    else:
        print('check the Te_model!!!')
        print("no model")
        return
    
    basedir = "/home/astrodoo/projects/rrg-dhaggard/astrodoo/EHT_bhoss/BHOSS_outcomes"
    datadir = os.path.join(basedir,model_str)
    outdir = os.path.join(basedir,"bhoss2hdf5",model_str)
    
    #ind_start=400
    #ind_end=400
    for image_ind in range(ind_start,ind_end+1):
        print("%d out of %d"%(image_ind,ind_end))
        
        data_name="%s_sig%d_i%d_ph%d_SgrA_Th_IMAGE_GRMHD_HAMR3D_EHT_%s_%d.dat" \
                  %(Te_model,sig,inclination,phi0,model_name,image_ind)
        
        bhdata = bhoss.read_image(os.path.join(datadir,data_name),silent=True,ifreq=2)
        bhdata.dump2hdf5(outdir=outdir,source=source,sigmacut=sig,acc=acc, \
                         betacrit=betacrit, f_ana=f_ana, normflux=2., tilt=0., silent=True)

# %%
bhoss2hdf5(model_name='MADS41A93M',Te_model='f05_b1',inclination=10,sig=1,phi0=0,source='SgrA')
# Out:
# 101 out of 200
# 102 out of 200
# 103 out of 200
# 104 out of 200
# 105 out of 200
# 106 out of 200
# 107 out of 200
# 108 out of 200
# 109 out of 200
# 110 out of 200
# 111 out of 200
# 112 out of 200
# 113 out of 200
# 114 out of 200
# 115 out of 200
# 116 out of 200
# 117 out of 200
# 118 out of 200
# 119 out of 200
# 120 out of 200
# 121 out of 200
# 122 out of 200
# 123 out of 200
# 124 out of 200
# 125 out of 200
# 126 out of 200
# 127 out of 200
# 128 out of 200
# 129 out of 200
# 130 out of 200
# 131 out of 200
# 132 out of 200
# 133 out of 200
# 134 out of 200
# 135 out of 200
# 136 out of 200
# 137 out of 200
# 138 out of 200
# 139 out of 200
# 140 out of 200
# 141 out of 200
# 142 out of 200
# 143 out of 200
# 144 out of 200
# 145 out of 200
# 146 out of 200
# 147 out of 200
# 148 out of 200
# 149 out of 200
# 150 out of 200
# 151 out of 200
# 152 out of 200
# 153 out of 200
# 154 out of 200
# 155 out of 200
# 156 out of 200
# 157 out of 200
# 158 out of 200
# ...

# %%
bhoss2hdf5(model_name='MADS41A93M',Te_model='f05_b1',inclination=50,sig=1,phi0=0,source='SgrA')
# Out:
# 101 out of 200
# 102 out of 200
# 103 out of 200
# 104 out of 200
# 105 out of 200
# 106 out of 200
# 107 out of 200
# 108 out of 200
# 109 out of 200
# 110 out of 200
# 111 out of 200
# 112 out of 200
# 113 out of 200
# 114 out of 200
# 115 out of 200
# 116 out of 200
# 117 out of 200
# 118 out of 200
# 119 out of 200
# 120 out of 200
# 121 out of 200
# 122 out of 200
# 123 out of 200
# 124 out of 200
# 125 out of 200
# 126 out of 200
# 127 out of 200
# 128 out of 200
# 129 out of 200
# 130 out of 200
# 131 out of 200
# 132 out of 200
# 133 out of 200
# 134 out of 200
# 135 out of 200
# 136 out of 200
# 137 out of 200
# 138 out of 200
# 139 out of 200
# 140 out of 200
# 141 out of 200
# 142 out of 200
# 143 out of 200
# 144 out of 200
# 145 out of 200
# 146 out of 200
# 147 out of 200
# 148 out of 200
# 149 out of 200
# 150 out of 200
# 151 out of 200
# 152 out of 200
# 153 out of 200
# 154 out of 200
# 155 out of 200
# 156 out of 200
# 157 out of 200
# 158 out of 200
# ...

# %%
bhoss2hdf5(model_name='MADS41A93M',Te_model='f05_b1',inclination=90,sig=1,phi0=0,source='SgrA')
# Out:
# 101 out of 200
# 102 out of 200
# 103 out of 200
# 104 out of 200
# 105 out of 200
# 106 out of 200
# 107 out of 200
# 108 out of 200
# 109 out of 200
# 110 out of 200
# 111 out of 200
# 112 out of 200
# 113 out of 200
# 114 out of 200
# 115 out of 200
# 116 out of 200
# 117 out of 200
# 118 out of 200
# 119 out of 200
# 120 out of 200
# 121 out of 200
# 122 out of 200
# 123 out of 200
# 124 out of 200
# 125 out of 200
# 126 out of 200
# 127 out of 200
# 128 out of 200
# 129 out of 200
# 130 out of 200
# 131 out of 200
# 132 out of 200
# 133 out of 200
# 134 out of 200
# 135 out of 200
# 136 out of 200
# 137 out of 200
# 138 out of 200
# 139 out of 200
# 140 out of 200
# 141 out of 200
# 142 out of 200
# 143 out of 200
# 144 out of 200
# 145 out of 200
# 146 out of 200
# 147 out of 200
# 148 out of 200
# 149 out of 200
# 150 out of 200
# 151 out of 200
# 152 out of 200
# 153 out of 200
# 154 out of 200
# 155 out of 200
# 156 out of 200
# 157 out of 200
# 158 out of 200
# ...
