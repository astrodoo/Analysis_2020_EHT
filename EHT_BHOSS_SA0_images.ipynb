# %% [markdown]
# # Rhigh & Rlow model (Moscibrodzka+16)

# %%
from pyhamrds import bhoss
import os
def bhoss_img(Rhigh,inclination,model_name):

    note=""
    if (model_name == "MADS41A5"):
        model_str = "bhoss_MA05"
        ind_start = 311
        ind_end = 410
    elif (model_name == "MADS41A0"):
        model_str = "bhoss_MA0"
        ind_start = 97
        ind_end = 196
    elif (model_name == "MADS41A93"):
        model_str = "bhoss_MA93"
        ind_start = 96
        ind_end = 195
    elif (model_name == "MADS41A93M"):
        model_str = "bhoss_MA93M"
        ind_start = 101
        ind_end = 200
    elif (model_name == "SANEA93M"):
        model_str = "bhoss_SA93M"
        ind_start=132
        ind_end = 231
    elif (model_name == "SANEA93"):
        model_str = "bhoss_SA93"
        ind_start=99
        ind_end = 198
    elif (model_name == "SANEA05"):
        model_str = "bhoss_SA05"
        ind_start=900
        ind_end = 999
        note="192_"
    elif (model_name == "SANEA0"):
        model_str = "bhoss_SA0"
        ind_start=640
        ind_end = 739
    else:
        print("no model")
        return
    
    basedir = "/home/astrodoo/projects/rrg-dhaggard/astrodoo/EHT_bhoss/BHOSS_outcomes"
    datadir = os.path.join(basedir,model_str)
    outdir = os.path.join(basedir,"images",model_str)
    
    #ind_start=650
    #ind_end=650
    for image_ind in range(ind_start,ind_end+1):
        print("%d out of %d"%(image_ind,ind_end))
        
        fname_base = "Rhigh_%d_incl_%d_IMAGE_GRMHD_HAMR3D_%s_%s%d"%(Rhigh,inclination,model_name,note,image_ind)
        data_name  = fname_base+".dat"
        out_name   = fname_base+".png"
        strannot="SgrA Th HAMR Rh%d i%d %s_%d"%(Rhigh,inclination,model_str[6:],image_ind)
        
        bhoss.show_image(os.path.join(datadir,data_name),ifreq=0,cmap='hot',strannot=strannot, \
                         out=os.path.join(outdir,out_name),silent=True,no_display=True)

# %%
bhoss_img(1,10,"SANEA0")
# Out:
# 650 out of 650

# %% [markdown]
# ## Produce images

# %%
bhoss_img(1,10,"SANEA0")
# Out:
# 640 out of 739
# 641 out of 739
# 642 out of 739
# 643 out of 739
# 644 out of 739
# 645 out of 739
# 646 out of 739
# 647 out of 739
# 648 out of 739
# 649 out of 739
# 650 out of 739
# 651 out of 739
# 652 out of 739
# 653 out of 739
# 654 out of 739
# 655 out of 739
# 656 out of 739
# 657 out of 739
# 658 out of 739
# 659 out of 739
# 660 out of 739
# 661 out of 739
# 662 out of 739
# 663 out of 739
# 664 out of 739
# 665 out of 739
# 666 out of 739
# 667 out of 739
# 668 out of 739
# 669 out of 739
# 670 out of 739
# 671 out of 739
# 672 out of 739
# 673 out of 739
# 674 out of 739
# 675 out of 739
# 676 out of 739
# 677 out of 739
# 678 out of 739
# 679 out of 739
# 680 out of 739
# 681 out of 739
# 682 out of 739
# 683 out of 739
# 684 out of 739
# 685 out of 739
# 686 out of 739
# 687 out of 739
# 688 out of 739
# 689 out of 739
# 690 out of 739
# 691 out of 739
# 692 out of 739
# 693 out of 739
# 694 out of 739
# 695 out of 739
# 696 out of 739
# 697 out of 739
# ...

# %%
bhoss_img(1,50,"SANEA0")
# Out:
# 640 out of 739
# 641 out of 739
# 642 out of 739
# 643 out of 739
# 644 out of 739
# 645 out of 739
# 696 out of 739
# 697 out of 739
# ...

# %%
bhoss_img(160,50,"SANEA0")
# Out:
# 640 out of 739
# 641 out of 739
# 642 out of 739
# 643 out of 739
# 644 out of 739
# 645 out of 739
# 646 out of 739
# 647 out of 739
# 648 out of 739
# 649 out of 739
# 650 out of 739
# 651 out of 739
# 652 out of 739
# 653 out of 739
# 654 out of 739
# 655 out of 739
# 656 out of 739
# 657 out of 739
# 658 out of 739
# 659 out of 739
# 660 out of 739
# 661 out of 739
# 662 out of 739
# 663 out of 739
# 664 out of 739
# 665 out of 739
# 666 out of 739
# 667 out of 739
# 668 out of 739
# 669 out of 739
# 670 out of 739
# 671 out of 739
# 672 out of 739
# 673 out of 739
# 674 out of 739
# 675 out of 739
# 676 out of 739
# 677 out of 739
# 678 out of 739
# 679 out of 739
# 680 out of 739
# 681 out of 739
# 682 out of 739
# 683 out of 739
# 684 out of 739
# 685 out of 739
# 686 out of 739
# 687 out of 739
# 688 out of 739
# 689 out of 739
# 690 out of 739
# 691 out of 739
# 692 out of 739
# 693 out of 739
# 694 out of 739
# 695 out of 739
# 696 out of 739
# 697 out of 739
# ...

# %%
bhoss_img(160,90,"SANEA0")
# Out:
# 640 out of 739
# 641 out of 739
# 642 out of 739
# 643 out of 739
# 644 out of 739
# 645 out of 739
# 646 out of 739
# 647 out of 739
# 648 out of 739
# 649 out of 739
# 650 out of 739
# 651 out of 739
# 652 out of 739
# 653 out of 739
# 654 out of 739
# 655 out of 739
# 656 out of 739
# 657 out of 739
# 658 out of 739
# 659 out of 739
# 660 out of 739
# 661 out of 739
# 662 out of 739
# 663 out of 739
# 664 out of 739
# 665 out of 739
# 666 out of 739
# 667 out of 739
# 668 out of 739
# 669 out of 739
# 670 out of 739
# 671 out of 739
# 672 out of 739
# 673 out of 739
# 674 out of 739
# 675 out of 739
# 676 out of 739
# 677 out of 739
# 678 out of 739
# 679 out of 739
# 680 out of 739
# 681 out of 739
# 682 out of 739
# 683 out of 739
# 684 out of 739
# 685 out of 739
# 686 out of 739
# 687 out of 739
# 688 out of 739
# 689 out of 739
# 690 out of 739
# 691 out of 739
# 692 out of 739
# 693 out of 739
# 694 out of 739
# 695 out of 739
# 696 out of 739
# 697 out of 739
# ...

# %% [markdown]
# # Critical beta model (Anantua+20)

# %%
from pyhamrds import bhoss
import os

#datadir = '/ccs/home/astrodoo/MEMW/BHOSS/BHOSS_CODE/outcomes/C3D2R512'
#data = 'GRRT_IMAGE_bhoss_data80.dat'

datadir = "/home/astrodoo/projects/rrg-dhaggard/astrodoo/EHT_bhoss/BHOSS_outcomes/bhoss_SA0"
data = "f05_b1_incl_90_IMAGE_GRMHD_HAMR3D_SANEA0_650.dat"

bhdata = bhoss.read_image(os.path.join(datadir,data),silent=False,ifreq=2)  # Koushik's data - only 230GHz
# Out:
# ===================================== header ==================================
# width: 20.134000 Rg, offset: 0.000000 Rg, resolution: 400, Number of obs. freqs: 5
# time: 9107.679785 Rg/c, inclination: 90.000000 deg, phi: 0.000000 deg, BH spin: 0.000000
# Luminosity correction: 4.762071e+22, Jansky correction: 6.025933e-01, Micro Arcsecond correction: 5.029644e+00
# Frequencies of intereset [GHz]: [  43.   86.  230.  345. 1360.]
# All-freq image is included (3rd column in image data): False
# ...
# length of data: 480000
# xmin: -101.266842, xmax: 101.266842, ymin: -101.266842, ymax: 101.266842
# intensity (min,max)= 0.0 0.00792398
# Total flux = 1.660761 Jy at 230 GHz

# %% [raw]
# from pyhamrds import bhoss
# import matplotlib.pyplot as plt
# import os
# %matplotlib inline
#
# basedir = "/home/astrodoo/projects/rrg-dhaggard/astrodoo/EHT_bhoss/BHOSS_outcomes"
# datadir = os.path.join(basedir,"bhoss_MA05")
# data = "f05_b1_sig1_i10_ph0_SgrA_Th_IMAGE_GRMHD_HAMR3D_EHT_MADS41A5_410.dat"
# outdir = os.path.join(basedir,"images","bhoss_MA05")
#
# filename  = os.path.join(datadir, data)
#
# figdir = os.environ['PYTHONFIG']
# #bhoss.show_image(filename,ifreq=10,cmap='hot',out=os.path.join(figdir,'bhoss_img_David512_201.png'))
# #bhoss.show_image(filename,ifreq=0,cmap='hot',strannot='Rh10', out=os.path.join(outdir,'test.png'), silent=True)
# #bhoss.show_image(filename,ifreq=0,cmap='hot',strannot='Rh10')

# %%
from pyhamrds import bhoss
import os
def bhoss_img(Te_model,inclination,model_name):

    note=""
    if (model_name == "MADS41A5"):
        model_str = "bhoss_MA05"
        ind_start = 311
        ind_end = 410
    elif (model_name == "MADS41A0"):
        model_str = "bhoss_MA0"
        ind_start = 97
        ind_end = 196
    elif (model_name == "MADS41A93M"):
        model_str = "bhoss_MA93M"
        ind_start = 101
        ind_end = 200
    elif (model_name == "MADS41A93"):
        model_str = "bhoss_MA93"
        ind_start = 96
        ind_end = 195
    elif (model_name == "SANEA93M"):
        model_str = "bhoss_SA93M"
        ind_start=132
        ind_end = 231
    elif (model_name == "SANEA93"):
        model_str = "bhoss_SA93"
        ind_start=99
        ind_end = 198
    elif (model_name == "SANEA05"):
        model_str = "bhoss_SA05"
        ind_start=900
        ind_end = 999
        note="192_"
    elif (model_name == "SANEA0"):
        model_str = "bhoss_SA0"
        ind_start=640
        ind_end = 739
    else:
        print("no model")
        return
    
    basedir = "/home/astrodoo/projects/rrg-dhaggard/astrodoo/EHT_bhoss/BHOSS_outcomes"
    datadir = os.path.join(basedir,model_str)
    outdir = os.path.join(basedir,"images",model_str)
    
    #ind_start=650
    #ind_end=650
    for image_ind in range(ind_start,ind_end+1):
        print("%d out of %d"%(image_ind,ind_end))
    
        fname_base = "%s_incl_%d_IMAGE_GRMHD_HAMR3D_%s_%d"%(Te_model,inclination,model_name,image_ind)
        fname_base = "%s_incl_%d_IMAGE_GRMHD_HAMR3D_%s_%s%d"%(Te_model,inclination,model_name,note,image_ind)
        data_name  = fname_base+".dat"
        out_name   = fname_base+".png"
        strannot="SgrA Th HAMR %s i%d %s_%d"%(Te_model,inclination,model_str[6:],image_ind)
    
        bhoss.show_image(os.path.join(datadir,data_name),ifreq=2,cmap='hot',strannot=strannot, \
                         out=os.path.join(outdir,out_name),silent=True,no_display=True)

# %%
bhoss_img("f05_b1",10,"SANEA0")
# Out:
# 650 out of 650

# %% [markdown]
# ## produce images

# %%
bhoss_img("f05_b1",10,"SANEA0")
# Out:
# 640 out of 739
# 641 out of 739
# 642 out of 739
